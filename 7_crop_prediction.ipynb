# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("7_Crop_recommendation.csv")

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.shape
# Out:
# (2200, 8)

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#no null value---> data is perfect

# %%
x=df.drop('label',axis=1)
y=df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((1760, 7), (440, 7), (1760,), (440,))

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)

# %%
# accuracy

# %%
accuracy=model.score(X_test,Y_test)

# %%
accuracy
# Out:
# 0.9931818181818182

# %%
new_features=[[60,55,44,23.004459,80.158363,6.980401,242.864034]]
predicted_crop=model.predict(new_features)
print("Predicted crop :",predicted_crop)
# Out:
# Predicted crop : ['rice']
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(model,open('7_randomForest_model.pkl','wb'))
